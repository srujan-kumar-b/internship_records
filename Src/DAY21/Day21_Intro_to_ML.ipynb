# %% [markdown]
# Machine Learning (ML) is a way of programming where instead of writing fixed rules for the computer to follow, we give it examples of data along with the correct answers, and it learns patterns from that data. In traditional programming, we manually define the logic to solve a problem, but in machine learning, the system automatically discovers the rules by analyzing large amounts of data. Once trained, the model can use the learned patterns to make predictions or decisions on new, unseen data.
